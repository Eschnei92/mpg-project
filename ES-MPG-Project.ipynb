# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


mpgal = sns.load_dataset("mpg")
sns.set(style="darkgrid")

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
#Create a visual showing the relationship between horsepower and fuel economy.
#Create a table summarizing fuel economy by country of origin
#Create a visual showing how fuel economy has changed over time
#Create two other visuals or tables related to fuel economy.
#Add comments to your notebook with your observations.

# %%
#Create a visual showing the relationship between horsepower and fuel economy.

sns.lineplot(
    data=mpgal, 
  x="horsepower", y="mpg",
    color='green',
    linewidth=2
    )
plt.title("MPG change relative to horsepower")
# Out:
# Text(0.5, 1.0, 'MPG change relative to horsepower')

# %%
#Create a table summarizing fuel economy by country of origin

mpg_data = sns.load_dataset('mpg')

summ_table = mpg_data.groupby('origin')['mpg'].agg(['mean', 'median']) 

summ_table['mean'] = summ_table['mean'].round(1)  

print("MPG by Country of Origin")  
print(summ_table)
# Out:
# MPG by Country of Origin
#         mean  median
# origin
# europe  27.9    26.5
# japan   30.5    31.6
# usa     20.1    18.5

# %%
#Create a visual showing how fuel economy has changed over time
sns.lineplot(
    data=mpgal, 
  x="model_year", y="mpg",
    color='blue',
    linewidth=2
    )
plt.title("MPG change over time")
plt.xlabel("Model Year")
plt.ylabel("MPG")
# Out:
# Text(0, 0.5, 'MPG')

# %%
#Create two other visuals or tables related to fuel economy(1).

sns.lineplot(
    data=mpgal, 
  x="cylinders", y="mpg",
    color='red',
    linewidth=2)
plt.title("Cylinders affect on MPG")
plt.xlabel("Cylinders")
plt.ylabel("MPG")

sns.relplot(
    data=mpgal, 
  x="cylinders", y="mpg",
    color='red',
    linewidth=2,
    col="origin",
    kind="line",
)

# %%
#Create two other visuals or tables related to fuel economy(2).

sns.regplot(
    data=mpgal, 
  x="weight", y="mpg",
)
plt.title("Weight's affect on MPG")
plt.xlabel("Weight")
plt.ylabel("MPG")
# Out:
# Text(0, 0.5, 'MPG')
